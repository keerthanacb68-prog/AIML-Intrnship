# %%
import pandas as pd
data ={
    'Location':['New York', 'new york', 'NEW YORK', 'New york', 'new York']
}
df = pd.DataFrame(data)

# %%
df
# Out:
#    Location
# 0  New York
# 1  new york
# 2  NEW YORK
# 3  New york
# 4  new York

# %%
df['Location'].unique()
# Out:
# array(['New York', 'new york', 'NEW YORK', 'New york', 'new York'],
#       dtype=object)

# %%
df['Location']=df['Location'].str.strip().str.title()

# %%
df
# Out:
#    Location
# 0  New York
# 1  New York
# 2  New York
# 3  New York
# 4  New York

# %%
df['Location'].unique()
# Out:
# array(['New York'], dtype=object)
