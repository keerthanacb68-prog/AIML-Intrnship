# %%
import pandas as pd
usernames = pd.Series(['Alice', 'bOB', 'Charlie_Data', 'daisy'])

# %%
cleaned = usernames.str.strip()

# %%
cleaned = cleaned.str.lower()

# %%
contains_a = cleaned.str.contains('a')

# %%
print("cleaned Series:\n",cleaned)
print("\nboolean result of the  'a' search :\n",contains_a)
# Out:
# cleaned Series:
#  0           alice
# 1             bob
# 2    charlie_data
# 3           daisy
# dtype: object
#
# boolean result of the  'a' search :
#  0     True
# 1    False
# 2     True
# 3     True
# dtype: bool
