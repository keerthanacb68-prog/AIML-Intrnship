# %%
import pandas as pd
results = pd.Series([85, None, 92, 45, None, 78, 55])

# %%
filled_series = results.fillna(0)

# %%
filtered_results = filled_results[filled_results >60]

# %%
print("Original_Series:\n",grades)
print("\nFilled_Series:\n",filled_grades)
print("\nFiltered Results (> 60):\n",filtered_results)
# Out:
# Original_Series:
#  0    85.0
# 1     NaN
# 2    92.0
# 3    45.0
# 4     NaN
# 5    78.0
# 6    55.0
# dtype: float64
#
# Filled_Series:
#  0    85.0
# 1     0.0
# 2    92.0
# 3    45.0
# 4     0.0
# 5    78.0
# 6    55.0
# dtype: float64
#
# Filtered Results (> 60):
#  0    85.0
# 2    92.0
# 5    78.0
# dtype: float64
